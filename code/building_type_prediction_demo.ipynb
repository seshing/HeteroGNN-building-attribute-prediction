# %%
import torch
import random
import os
import pandas as pd
import numpy as np
import torch
import torch.nn.functional as F
from model import HeteroSAGEFull, HeteroSAGE
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from urbanity.data_class import UrbanGraph
from embedding import embedding_images, build_knn_graph
from utils import to_pyg_graph, HeteroSAGEEmbed
from sklearn.metrics import precision_score, recall_score
from torch_geometric.transforms import FeaturePropagation

seed = 0
random.seed(seed); np.random.seed(seed); torch.manual_seed(seed); torch.cuda.manual_seed_all(seed)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
project_path  = f'YOUR_PROJECT_PATH'
os.chdir(project_path)
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# ## **1. Data Preparation**

# %% [markdown]
# ### **1.1 Parameter settings**

# %%
city = 'Washington'
label_path   = f'data/building_type/{city}.csv'
graph_path  = f'data/urban_graph/{city}.zip'

output_path = f'output'
cache_path = f'output/cache'
os.makedirs(output_path, exist_ok=True)
os.makedirs(cache_path, exist_ok=True)

lr             = 5e-3
hidden_dim     = 256
batch_size     = 64
EPOCH          = 500
knn            = 5
distance       = 100
label_col_name = 'building_type_osm'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### **1.2 Divide train, validation and test sets**

# %%
df_labels = pd.read_csv(label_path).drop_duplicates('building_id')
df_labels.building_id = df_labels.building_id.astype(str)
df_labels[label_col_name] = df_labels[label_col_name].astype('category')
num_classes = len(df_labels[label_col_name].cat.categories)

# load urban graph
graph = UrbanGraph()
graph.load_graph(graph_path)
graph.initialize_edges(building_neighbours='knn', knn=knn, distance=distance)
buildings = graph.building
df_labels = df_labels[df_labels['building_id'].isin(buildings['bid'].values)]


train_df, temp_df = train_test_split(
    df_labels, test_size=0.4,
    stratify=df_labels[label_col_name], random_state=seed
)
val_df, test_df = train_test_split(
    temp_df, test_size=0.5,
    stratify=temp_df[label_col_name], random_state=seed
)

all_bids = list(df_labels['building_id'].astype(str).values)
all_bids_graph = list(buildings['bid'].astype(str).values)
bid2node = {bid: idx for idx, bid in enumerate(all_bids_graph)}

train_bids = train_df.building_id.tolist()
val_bids   = val_df.building_id.tolist()
test_bids  = test_df.building_id.tolist()

train_idx = [bid2node[bid] for bid in train_bids]
val_idx   = [bid2node[bid] for bid in val_bids]
test_idx  = [bid2node[bid] for bid in test_bids]

y_target = np.full(len(all_bids_graph), -1, dtype=int)
class_map = {cat: i for i,cat in enumerate(df_labels[label_col_name].cat.categories)}
for bid, cat in zip(df_labels.building_id, df_labels[label_col_name]):
    y_target[bid2node[bid]] = class_map[cat]
    
data = to_pyg_graph(graph.geo_store, graph.edge_store, target_col='building', target_value=y_target.tolist())

valid_y = data['building'].y[data['building'].y >= 0]
unique, counts = np.unique(valid_y.cpu().numpy(), return_counts=True)
value_counts = dict(zip(unique, counts))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
train_set = df_labels[df_labels['building_id'].isin(train_bids)]
labels_train = train_set[label_col_name].map(lambda x: class_map[x]).values
class_counts = np.bincount(labels_train)
print("Class counts:", class_counts)
total = labels_train.size
weights = total / (num_classes * class_counts.astype(np.float32))

class_weights = torch.tensor(weights, dtype=torch.float32).to(device)
print("Class weights:", class_weights)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Class counts: [  449   238 18893   174   194 25605    22   131    41    73  8852]
# Class weights: tensor([1.1069e+01, 2.0883e+01, 2.6307e-01, 2.8564e+01, 2.5619e+01, 1.9411e-01,
#         2.2592e+02, 3.7940e+01, 1.2122e+02, 6.8085e+01, 5.6148e-01],
#        device='cuda:0')

# %% [markdown]
# ## **2. HeteroGNN** (urban features only)

# %% [markdown]
# ### **2.1 Training**

# %%
data = data.to(device)
model = HeteroSAGEFull(hidden_channels=hidden_dim, out_channels=num_classes, dropout_rate=0.2).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

best_epoch = 0
best_val_loss = float('inf')
patience_counter = 0
PATIENCE = 50

for epoch in range(EPOCH):
    model.train()
    optimizer.zero_grad()

    out = model(data.x_dict, data.edge_index_dict)
    train_loss = F.cross_entropy(
        out[train_idx],
        data['building'].y[train_idx],
        weight=class_weights
    )
    train_loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict)
        val_loss = F.cross_entropy(
            out[val_idx],
            data['building'].y[val_idx]
        )
        all_preds = out[val_idx].argmax(dim=1).cpu().numpy()
        all_labels = data['building'].y[val_idx].cpu().numpy()
        avg_acc = (all_preds == all_labels).mean()
        macro_f1 = f1_score(all_labels, all_preds, average='macro')
        
        if epoch % 10 == 0:
            print(f'Epoch: {epoch} | Train Loss: {train_loss.item():.5f}')
            print(f'Epoch: {epoch} | Val Loss: {val_loss.item():.5f} | Accuracy: {avg_acc:.5f} | Macro F1: {macro_f1:.5f}')
        
        if val_loss < best_val_loss and epoch > 10:
            best_val_loss = val_loss
            best_epoch = epoch
            torch.save(model.state_dict(), os.path.join(output_path, f'best_model.pth'))
            print(f"Best model saved for epoch {epoch} with Val Loss: {best_val_loss:.5f}")
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter % 10 == 0:
                print(f"No improvement for {patience_counter} epochs.")

    if patience_counter >= PATIENCE:
        print(f"Early stopping triggered at epoch {epoch} after {PATIENCE} epochs without improvement.")
        break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Epoch: 0 | Train Loss: 2.39595
# Epoch: 0 | Val Loss: 2.58365 | Accuracy: 0.00521 | Macro F1: 0.04315
# No improvement for 10 epochs.
# Epoch: 10 | Train Loss: 1.10621
# Epoch: 10 | Val Loss: 0.92230 | Accuracy: 0.68163 | Macro F1: 0.36748
# Best model saved for epoch 11 with Val Loss: 0.75844
# Best model saved for epoch 15 with Val Loss: 0.71186
# Best model saved for epoch 16 with Val Loss: 0.64830
# Best model saved for epoch 19 with Val Loss: 0.63843
# Epoch: 20 | Train Loss: 0.73459
# Epoch: 20 | Val Loss: 0.61228 | Accuracy: 0.77041 | Macro F1: 0.43722
# Best model saved for epoch 20 with Val Loss: 0.61228
# Best model saved for epoch 23 with Val Loss: 0.60757
# Best model saved for epoch 24 with Val Loss: 0.58391
# Best model saved for epoch 25 with Val Loss: 0.56606
# Epoch: 30 | Train Loss: 0.51369
# Epoch: 30 | Val Loss: 0.56199 | Accuracy: 0.78441 | Macro F1: 0.46808
# Best model saved for epoch 30 with Val Loss: 0.56199
# Best model saved for epoch 31 with Val Loss: 0.53780
# Best model saved for epoch 32 with Val Loss: 0.53537
# Best model saved for epoch 36 with Val Loss: 0.53009
# Best model saved for epoch 37 with Val Loss: 0.51173
# Epoch: 40 | Train Loss: 0.36468
# Epoch: 40 | Val Loss: 0.49697 | Accuracy: 0.81195 | Macro F1: 0.50971
# Best model saved for epoch 40 with Val Loss: 0.49697
# Best model saved for epoch 45 with Val Loss: 0.48623
# Best model saved for epoch 48 with Val Loss: 0.48206
# Best model saved for epoch 49 with Val Loss: 0.47906
# Epoch: 50 | Train Loss: 0.29632
# Epoch: 50 | Val Loss: 0.47162 | Accuracy: 0.82732 | Macro F1: 0.50436
# Best model saved for epoch 50 with Val Loss: 0.47162
# Best model saved for epoch 53 with Val Loss: 0.46508
# Best model saved for epoch 55 with Val Loss: 0.46364
# Best model saved for epoch 56 with Val Loss: 0.44808
# Best model saved for epoch 59 with Val Loss: 0.43037
# Epoch: 60 | Train Loss: 0.23881
# Epoch: 60 | Val Loss: 0.45250 | Accuracy: 0.83807 | Macro F1: 0.51577
# Best model saved for epoch 65 with Val Loss: 0.42228
# Best model saved for epoch 69 with Val Loss: 0.41762
# Epoch: 70 | Train Loss: 0.18631
# Epoch: 70 | Val Loss: 0.42226 | Accuracy: 0.84614 | Macro F1: 0.54189
# Best model saved for epoch 75 with Val Loss: 0.40992
# Best model saved for epoch 78 with Val Loss: 0.40231
# Epoch: 80 | Train Loss: 0.16882
# Epoch: 80 | Val Loss: 0.42725 | Accuracy: 0.85058 | Macro F1: 0.54975
# Best model saved for epoch 83 with Val Loss: 0.38638
# Best model saved for epoch 89 with Val Loss: 0.37556
# Epoch: 90 | Train Loss: 0.14822
# Epoch: 90 | Val Loss: 0.41009 | Accuracy: 0.85448 | Macro F1: 0.54986
# Best model saved for epoch 94 with Val Loss: 0.37189
# Epoch: 100 | Train Loss: 0.13424
# Epoch: 100 | Val Loss: 0.36961 | Accuracy: 0.87659 | Macro F1: 0.57273
# Best model saved for epoch 100 with Val Loss: 0.36961
# Best model saved for epoch 105 with Val Loss: 0.35261
# Epoch: 110 | Train Loss: 0.12121
# Epoch: 110 | Val Loss: 0.35970 | Accuracy: 0.88252 | Macro F1: 0.56414
# No improvement for 10 epochs.
# Best model saved for epoch 118 with Val Loss: 0.33864
# Epoch: 120 | Train Loss: 0.10856
# Epoch: 120 | Val Loss: 0.36883 | Accuracy: 0.88208 | Macro F1: 0.56558
# No improvement for 10 epochs.
# Epoch: 130 | Train Loss: 0.10583
# Epoch: 130 | Val Loss: 0.34033 | Accuracy: 0.89086 | Macro F1: 0.55641
# Best model saved for epoch 135 with Val Loss: 0.33256
# Epoch: 140 | Train Loss: 0.09957
# Epoch: 140 | Val Loss: 0.33621 | Accuracy: 0.89453 | Macro F1: 0.57035
# Best model saved for epoch 142 with Val Loss: 0.32274
# Best model saved for epoch 149 with Val Loss: 0.31322
# Epoch: 150 | Train Loss: 0.09273
# Epoch: 150 | Val Loss: 0.34695 | Accuracy: 0.89086 | Macro F1: 0.59366
# Best model saved for epoch 159 with Val Loss: 0.31024
# Epoch: 160 | Train Loss: 0.08927
# Epoch: 160 | Val Loss: 0.33567 | Accuracy: 0.89464 | Macro F1: 0.58535
# Best model saved for epoch 164 with Val Loss: 0.30687
# Best model saved for epoch 167 with Val Loss: 0.29716
# Epoch: 170 | Train Loss: 0.08664
# Epoch: 170 | Val Loss: 0.30441 | Accuracy: 0.90694 | Macro F1: 0.59869
# Best model saved for epoch 175 with Val Loss: 0.28766
# Epoch: 180 | Train Loss: 0.08380
# Epoch: 180 | Val Loss: 0.30080 | Accuracy: 0.91155 | Macro F1: 0.60782
# Best model saved for epoch 184 with Val Loss: 0.28103
# Epoch: 190 | Train Loss: 0.07856
# Epoch: 190 | Val Loss: 0.28587 | Accuracy: 0.91577 | Macro F1: 0.60790
# No improvement for 10 epochs.
# Epoch: 200 | Train Loss: 0.07106
# Epoch: 200 | Val Loss: 0.28443 | Accuracy: 0.91764 | Macro F1: 0.60905
# No improvement for 20 epochs.
# Epoch: 210 | Train Loss: 0.07164
# Epoch: 210 | Val Loss: 0.28075 | Accuracy: 0.91868 | Macro F1: 0.62600
# Best model saved for epoch 210 with Val Loss: 0.28075
# Best model saved for epoch 213 with Val Loss: 0.27690
# Epoch: 220 | Train Loss: 0.07035
# Epoch: 220 | Val Loss: 0.28154 | Accuracy: 0.91725 | Macro F1: 0.62497
# Best model saved for epoch 222 with Val Loss: 0.27653
# Epoch: 230 | Train Loss: 0.06786
# Epoch: 230 | Val Loss: 0.29053 | Accuracy: 0.91478 | Macro F1: 0.62106
# No improvement for 10 epochs.
# Best model saved for epoch 233 with Val Loss: 0.27630
# Best model saved for epoch 236 with Val Loss: 0.27133
# Best model saved for epoch 239 with Val Loss: 0.26935
# Epoch: 240 | Train Loss: 0.06318
# Epoch: 240 | Val Loss: 0.28936 | Accuracy: 0.91610 | Macro F1: 0.63144
# Best model saved for epoch 241 with Val Loss: 0.26739
# Best model saved for epoch 248 with Val Loss: 0.26284
# Epoch: 250 | Train Loss: 0.06840
# Epoch: 250 | Val Loss: 0.26364 | Accuracy: 0.92433 | Macro F1: 0.62174
# Best model saved for epoch 251 with Val Loss: 0.26042
# Epoch: 260 | Train Loss: 0.06783
# Epoch: 260 | Val Loss: 0.26057 | Accuracy: 0.92636 | Macro F1: 0.62661
# No improvement for 10 epochs.
# Best model saved for epoch 266 with Val Loss: 0.25722
# Epoch: 270 | Train Loss: 0.06513
# Epoch: 270 | Val Loss: 0.26949 | Accuracy: 0.92625 | Macro F1: 0.61968
# Best model saved for epoch 273 with Val Loss: 0.25004
# Epoch: 280 | Train Loss: 0.06293
# Epoch: 280 | Val Loss: 0.25354 | Accuracy: 0.92828 | Macro F1: 0.63740
# No improvement for 10 epochs.
# Epoch: 290 | Train Loss: 0.05905
# Epoch: 290 | Val Loss: 0.25696 | Accuracy: 0.92795 | Macro F1: 0.65549
# No improvement for 20 epochs.
# Epoch: 300 | Train Loss: 0.05627
# Epoch: 300 | Val Loss: 0.26456 | Accuracy: 0.92510 | Macro F1: 0.63307
# No improvement for 30 epochs.
# Best model saved for epoch 304 with Val Loss: 0.24528
# Epoch: 310 | Train Loss: 0.06033
# Epoch: 310 | Val Loss: 0.25545 | Accuracy: 0.92812 | Macro F1: 0.63954
# Best model saved for epoch 312 with Val Loss: 0.24405
# Best model saved for epoch 314 with Val Loss: 0.24049
# Epoch: 320 | Train Loss: 0.05843
# Epoch: 320 | Val Loss: 0.25506 | Accuracy: 0.92878 | Macro F1: 0.63835
# No improvement for 10 epochs.
# Epoch: 330 | Train Loss: 0.05192
# Epoch: 330 | Val Loss: 0.24134 | Accuracy: 0.93558 | Macro F1: 0.65374
# No improvement for 20 epochs.
# Epoch: 340 | Train Loss: 0.05301
# Epoch: 340 | Val Loss: 0.24676 | Accuracy: 0.93289 | Macro F1: 0.63566
# Best model saved for epoch 341 with Val Loss: 0.23828
# Best model saved for epoch 344 with Val Loss: 0.23787
# Epoch: 350 | Train Loss: 0.05157
# Epoch: 350 | Val Loss: 0.24118 | Accuracy: 0.93684 | Macro F1: 0.63536
# Best model saved for epoch 352 with Val Loss: 0.23642
# Epoch: 360 | Train Loss: 0.04842
# Epoch: 360 | Val Loss: 0.24915 | Accuracy: 0.93371 | Macro F1: 0.64349
# Best model saved for epoch 361 with Val Loss: 0.23334
# Epoch: 370 | Train Loss: 0.05303
# Epoch: 370 | Val Loss: 0.24339 | Accuracy: 0.93734 | Macro F1: 0.62990
# No improvement for 10 epochs.
# Epoch: 380 | Train Loss: 0.05135
# Epoch: 380 | Val Loss: 0.25009 | Accuracy: 0.93481 | Macro F1: 0.61258
# No improvement for 20 epochs.
# Best model saved for epoch 389 with Val Loss: 0.23264
# Epoch: 390 | Train Loss: 0.05944
# Epoch: 390 | Val Loss: 0.25044 | Accuracy: 0.93377 | Macro F1: 0.63451
# No improvement for 10 epochs.
# Epoch: 400 | Train Loss: 0.05253
# Epoch: 400 | Val Loss: 0.24200 | Accuracy: 0.93706 | Macro F1: 0.63327
# No improvement for 20 epochs.
# Epoch: 410 | Train Loss: 0.05471
# Epoch: 410 | Val Loss: 0.23620 | Accuracy: 0.93838 | Macro F1: 0.61836
# Best model saved for epoch 418 with Val Loss: 0.23217
# Epoch: 420 | Train Loss: 0.04726
# Epoch: 420 | Val Loss: 0.24779 | Accuracy: 0.93443 | Macro F1: 0.62658
# Best model saved for epoch 421 with Val Loss: 0.22612
# Epoch: 430 | Train Loss: 0.04493
# Epoch: 430 | Val Loss: 0.22974 | Accuracy: 0.94288 | Macro F1: 0.63556
# No improvement for 10 epochs.
# Best model saved for epoch 435 with Val Loss: 0.22511
# Best model saved for epoch 436 with Val Loss: 0.22265
# Epoch: 440 | Train Loss: 0.04381
# Epoch: 440 | Val Loss: 0.24218 | Accuracy: 0.93755 | Macro F1: 0.64259
# Best model saved for epoch 442 with Val Loss: 0.22144
# Best model saved for epoch 445 with Val Loss: 0.22096
# Epoch: 450 | Train Loss: 0.04143
# Epoch: 450 | Val Loss: 0.24040 | Accuracy: 0.93755 | Macro F1: 0.63204
# Best model saved for epoch 451 with Val Loss: 0.21970
# Best model saved for epoch 458 with Val Loss: 0.21733
# Epoch: 460 | Train Loss: 0.04294
# Epoch: 460 | Val Loss: 0.23276 | Accuracy: 0.93937 | Macro F1: 0.63038
# Best model saved for epoch 468 with Val Loss: 0.21708
# Epoch: 470 | Train Loss: 0.04160
# Epoch: 470 | Val Loss: 0.22930 | Accuracy: 0.94255 | Macro F1: 0.63000
# No improvement for 10 epochs.
# Epoch: 480 | Train Loss: 0.03772
# Epoch: 480 | Val Loss: 0.23361 | Accuracy: 0.94332 | Macro F1: 0.63519
# No improvement for 20 epochs.
# Epoch: 490 | Train Loss: 0.03702
# Epoch: 490 | Val Loss: 0.22403 | Accuracy: 0.94441 | Macro F1: 0.63952
# Best model saved for epoch 494 with Val Loss: 0.21628

# %% [markdown]
# ### **2.2 Evaluate on test set**

# %%
print("\nEvaluating best model on test set...")
model.load_state_dict(torch.load(os.path.join(output_path, f'best_model.pth')))
model.eval()
with torch.no_grad():
    out = model(data.x_dict, data.edge_index_dict)
    test_loss = F.cross_entropy(
        out[test_idx],
        data['building'].y[test_idx]
    ).item()
    all_test_preds = out[test_idx].argmax(dim=1).cpu().numpy()
    all_test_labels = data['building'].y[test_idx].cpu().numpy()
    test_acc = (all_test_preds == all_test_labels).mean()
    test_macro_f1 = f1_score(all_test_labels, all_test_preds, average='macro')
    test_precision = precision_score(all_test_labels, all_test_preds, average='macro', zero_division=0)
    test_recall = recall_score(all_test_labels, all_test_preds, average='macro', zero_division=0)

    top2 = out[test_idx].topk(2, dim=1).indices
    true_labels = data['building'].y[test_idx].unsqueeze(1)
    test_top2_acc = (top2.eq(true_labels).sum(dim=1) > 0).float().mean().item()

    print(f'Test Loss: {test_loss:.5f} | Test Accuracy: {test_acc:.5f} | Test Macro F1: {test_macro_f1:.5f}')
    print(f'Test Precision: {test_precision:.5f} | Test Recall: {test_recall:.5f}')
    print(f'Test Top2 Accuracy: {test_top2_acc:.5f}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Evaluating best model on test set...
# Test Loss: 0.21372 | Test Accuracy: 0.94985 | Test Macro F1: 0.67491
# Test Precision: 0.67912 | Test Recall: 0.68278
# Test Top2 Accuracy: 0.98820

# %% [markdown]
# ## **3. HeteroGNN** (urban features + SVI)

# %% [markdown]
# ### **3.1 Visual feature extraction (SVI)**

# %%
svi_path        = f'data/svi/{city}'
embed_cv_model  = 'dinov3'
image_dimension = 256
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
svi_embed = embedding_images(
        image_type = 'SVI',
        model_name = embed_cv_model,
        image_path = svi_path,
        all_bids_graph = all_bids_graph,
        bid2node = bid2node,
        image_dimension = image_dimension,
        batch_size = batch_size,
        device = 'cuda',
        output_path = cache_path,
        city = city
        )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 84077 available images for SVI.
# Cache file loaded: Washington_SVI_256_dinov3_139076_84077.pt

# %% [markdown]
# ### **3.2 Visual feature propagation**

# %%
embed_graph_model = HeteroSAGEEmbed(hidden_channels=hidden_dim, out_channels=512).to(device)
ssg_path = os.path.join(cache_path, f'semantic_similarity_graph.pt')

if os.path.exists(ssg_path):
    print("Loading semantic similarity graph...")
    ssg = torch.load(ssg_path, weights_only=False)
else:
    print("Building homo_init and saving to cache...")
    ssg = build_knn_graph(embed_graph_model,
                                data, hidden_dim,
                                device, k=10, chunk_size=2048)
    torch.save(ssg, ssg_path)
    
ssg = ssg.to(device)
ssg.x = svi_embed.to(device)
missing_mask = torch.isnan(svi_embed)
ssg = FeaturePropagation(missing_mask=missing_mask, num_iterations=10)(ssg)

data = data.to(device)
data['building'].svi = ssg.x
data['building'].x = torch.cat([
    data['building'].x,
    data['building'].svi
], dim=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Loading semantic similarity graph...
# Building shape after embedding with svi image: torch.Size([139076, 271])

# %% [markdown]
# ### **3.3 Training**

# %%
model = HeteroSAGE(hidden_channels=hidden_dim, out_channels=num_classes, dropout_rate=.2).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
scheduler = ReduceLROnPlateau(optimizer, 'min', factor=0.8, patience=20, verbose=True)

best_epoch = 0
best_val_loss = float('inf')
patience_counter = 0
PATIENCE = 50

for epoch in range(EPOCH):
    model.train()
    optimizer.zero_grad()

    out = model(data.x_dict, data.edge_index_dict)
    train_loss = F.cross_entropy(
        out[train_idx],
        data['building'].y[train_idx],
        weight=class_weights
    )
    train_loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict)
        val_loss = F.cross_entropy(
            out[val_idx],
            data['building'].y[val_idx]
        )
        all_preds = out[val_idx].argmax(dim=1).cpu().numpy()
        all_labels = data['building'].y[val_idx].cpu().numpy()
        avg_acc = (all_preds == all_labels).mean()
        macro_f1 = f1_score(all_labels, all_preds, average='macro')
        
        scheduler.step(val_loss)
        
        if epoch % 10 == 0:
            print(f'Epoch: {epoch} | Train Loss: {train_loss.item():.5f}')
            print(f'Epoch: {epoch} | Val Loss: {val_loss.item():.5f} | Accuracy: {avg_acc:.5f} | Macro F1: {macro_f1:.5f}')
        
        if val_loss < best_val_loss and epoch > 10:
            best_val_loss = val_loss
            best_epoch = epoch
            torch.save(model.state_dict(), os.path.join(output_path, f'best_model.pth'))
            print(f"Best model saved for epoch {epoch} with Val Loss: {best_val_loss:.5f}")
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter % 10 == 0:
                print(f"No improvement for {patience_counter} epochs.")

    if patience_counter >= PATIENCE:
        print(f"Early stopping triggered at epoch {epoch} after {PATIENCE} epochs without improvement.")
        break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Epoch: 0 | Train Loss: 2.66571
# Epoch: 0 | Val Loss: 2.46473 | Accuracy: 0.02030 | Macro F1: 0.03480
# No improvement for 10 epochs.
# Epoch: 10 | Train Loss: 0.73345
# Epoch: 10 | Val Loss: 1.13032 | Accuracy: 0.66791 | Macro F1: 0.35407
# Best model saved for epoch 11 with Val Loss: 1.15154
# Best model saved for epoch 13 with Val Loss: 1.08553
# Best model saved for epoch 14 with Val Loss: 0.93643
# Best model saved for epoch 15 with Val Loss: 0.81199
# Best model saved for epoch 16 with Val Loss: 0.74188
# Best model saved for epoch 17 with Val Loss: 0.70626
# Epoch: 20 | Train Loss: 0.41731
# Epoch: 20 | Val Loss: 0.74917 | Accuracy: 0.75719 | Macro F1: 0.42583
# Best model saved for epoch 22 with Val Loss: 0.64106
# Best model saved for epoch 23 with Val Loss: 0.56656
# Best model saved for epoch 24 with Val Loss: 0.52122
# Best model saved for epoch 25 with Val Loss: 0.49972
# Best model saved for epoch 26 with Val Loss: 0.48300
# Best model saved for epoch 27 with Val Loss: 0.47020
# Best model saved for epoch 28 with Val Loss: 0.44554
# Best model saved for epoch 29 with Val Loss: 0.42014
# Epoch: 30 | Train Loss: 0.26786
# Epoch: 30 | Val Loss: 0.40075 | Accuracy: 0.86595 | Macro F1: 0.50722
# Best model saved for epoch 30 with Val Loss: 0.40075
# Best model saved for epoch 31 with Val Loss: 0.39661
# Best model saved for epoch 32 with Val Loss: 0.39600
# Best model saved for epoch 33 with Val Loss: 0.39348
# Best model saved for epoch 34 with Val Loss: 0.39244
# Best model saved for epoch 36 with Val Loss: 0.38119
# Best model saved for epoch 37 with Val Loss: 0.37365
# Best model saved for epoch 38 with Val Loss: 0.36418
# Best model saved for epoch 39 with Val Loss: 0.35082
# Epoch: 40 | Train Loss: 0.16595
# Epoch: 40 | Val Loss: 0.34266 | Accuracy: 0.88581 | Macro F1: 0.55342
# Best model saved for epoch 40 with Val Loss: 0.34266
# Best model saved for epoch 41 with Val Loss: 0.33925
# Best model saved for epoch 46 with Val Loss: 0.33904
# Best model saved for epoch 47 with Val Loss: 0.33258
# Best model saved for epoch 48 with Val Loss: 0.32704
# Epoch: 50 | Train Loss: 0.12084
# Epoch: 50 | Val Loss: 0.32708 | Accuracy: 0.89042 | Macro F1: 0.58378
# Best model saved for epoch 51 with Val Loss: 0.32414
# Best model saved for epoch 52 with Val Loss: 0.31879
# Epoch: 60 | Train Loss: 0.10608
# Epoch: 60 | Val Loss: 0.31346 | Accuracy: 0.89728 | Macro F1: 0.59176
# Best model saved for epoch 60 with Val Loss: 0.31346
# Best model saved for epoch 61 with Val Loss: 0.29989
# Best model saved for epoch 62 with Val Loss: 0.29292
# Epoch: 70 | Train Loss: 0.08832
# Epoch: 70 | Val Loss: 0.30929 | Accuracy: 0.89953 | Macro F1: 0.59741
# No improvement for 10 epochs.
# Best model saved for epoch 75 with Val Loss: 0.28634
# Best model saved for epoch 76 with Val Loss: 0.28521
# Best model saved for epoch 77 with Val Loss: 0.28516
# Best model saved for epoch 78 with Val Loss: 0.28497
# Best model saved for epoch 79 with Val Loss: 0.27373
# Epoch: 80 | Train Loss: 0.07522
# Epoch: 80 | Val Loss: 0.26770 | Accuracy: 0.91824 | Macro F1: 0.60898
# Best model saved for epoch 80 with Val Loss: 0.26770
# Best model saved for epoch 81 with Val Loss: 0.26335
# Best model saved for epoch 82 with Val Loss: 0.26156
# Best model saved for epoch 83 with Val Loss: 0.25841
# Best model saved for epoch 84 with Val Loss: 0.25819
# Best model saved for epoch 85 with Val Loss: 0.25619
# Best model saved for epoch 86 with Val Loss: 0.25370
# Best model saved for epoch 87 with Val Loss: 0.25145
# Epoch: 90 | Train Loss: 0.06567
# Epoch: 90 | Val Loss: 0.26358 | Accuracy: 0.91873 | Macro F1: 0.62470
# No improvement for 10 epochs.
# Epoch: 100 | Train Loss: 0.05876
# Epoch: 100 | Val Loss: 0.25355 | Accuracy: 0.92290 | Macro F1: 0.62764
# Best model saved for epoch 105 with Val Loss: 0.24999
# Best model saved for epoch 106 with Val Loss: 0.24536
# Best model saved for epoch 107 with Val Loss: 0.24017
# Best model saved for epoch 108 with Val Loss: 0.23374
# Best model saved for epoch 109 with Val Loss: 0.23291
# Epoch: 110 | Train Loss: 0.05071
# Epoch: 110 | Val Loss: 0.23867 | Accuracy: 0.93004 | Macro F1: 0.62276
# Best model saved for epoch 116 with Val Loss: 0.23027
# Best model saved for epoch 117 with Val Loss: 0.22944
# Epoch: 120 | Train Loss: 0.04974
# Epoch: 120 | Val Loss: 0.23581 | Accuracy: 0.93009 | Macro F1: 0.63013
# Best model saved for epoch 123 with Val Loss: 0.21932
# Best model saved for epoch 124 with Val Loss: 0.21482
# Epoch: 130 | Train Loss: 0.04849
# Epoch: 130 | Val Loss: 0.22364 | Accuracy: 0.93673 | Macro F1: 0.62782
# No improvement for 10 epochs.
# Best model saved for epoch 138 with Val Loss: 0.20398
# Epoch: 140 | Train Loss: 0.04773
# Epoch: 140 | Val Loss: 0.22809 | Accuracy: 0.93185 | Macro F1: 0.64712
# No improvement for 10 epochs.
# Epoch: 150 | Train Loss: 0.04641
# Epoch: 150 | Val Loss: 0.22429 | Accuracy: 0.93739 | Macro F1: 0.63512
# No improvement for 20 epochs.
# Epoch: 160 | Train Loss: 0.04558
# Epoch: 160 | Val Loss: 0.22851 | Accuracy: 0.93503 | Macro F1: 0.64279
# No improvement for 30 epochs.
# Epoch: 170 | Train Loss: 0.03648
# Epoch: 170 | Val Loss: 0.22236 | Accuracy: 0.93948 | Macro F1: 0.64121
# No improvement for 40 epochs.
# Epoch: 180 | Train Loss: 0.03217
# Epoch: 180 | Val Loss: 0.22455 | Accuracy: 0.93854 | Macro F1: 0.63865
# Best model saved for epoch 183 with Val Loss: 0.20283
# Best model saved for epoch 187 with Val Loss: 0.20219
# Best model saved for epoch 188 with Val Loss: 0.20137
# Best model saved for epoch 189 with Val Loss: 0.20075
# Epoch: 190 | Train Loss: 0.02864
# Epoch: 190 | Val Loss: 0.19938 | Accuracy: 0.94869 | Macro F1: 0.65498
# Best model saved for epoch 190 with Val Loss: 0.19938
# Best model saved for epoch 191 with Val Loss: 0.19742
# Epoch: 200 | Train Loss: 0.02578
# Epoch: 200 | Val Loss: 0.20864 | Accuracy: 0.94633 | Macro F1: 0.64967
# No improvement for 10 epochs.
# Best model saved for epoch 205 with Val Loss: 0.19542
# Epoch: 210 | Train Loss: 0.02599
# Epoch: 210 | Val Loss: 0.20707 | Accuracy: 0.94902 | Macro F1: 0.64426
# No improvement for 10 epochs.
# Best model saved for epoch 217 with Val Loss: 0.19460
# Epoch: 220 | Train Loss: 0.02406
# Epoch: 220 | Val Loss: 0.20512 | Accuracy: 0.94946 | Macro F1: 0.65716
# No improvement for 10 epochs.
# Epoch: 230 | Train Loss: 0.02260
# Epoch: 230 | Val Loss: 0.21215 | Accuracy: 0.94875 | Macro F1: 0.66088
# No improvement for 20 epochs.
# Epoch: 240 | Train Loss: 0.02048
# Epoch: 240 | Val Loss: 0.20254 | Accuracy: 0.95155 | Macro F1: 0.64056
# Best model saved for epoch 246 with Val Loss: 0.19144
# Epoch: 250 | Train Loss: 0.02011
# Epoch: 250 | Val Loss: 0.20410 | Accuracy: 0.95122 | Macro F1: 0.66979
# No improvement for 10 epochs.
# Epoch: 260 | Train Loss: 0.01849
# Epoch: 260 | Val Loss: 0.19815 | Accuracy: 0.95363 | Macro F1: 0.66057
# No improvement for 20 epochs.
# Epoch: 270 | Train Loss: 0.01783
# Epoch: 270 | Val Loss: 0.20033 | Accuracy: 0.95369 | Macro F1: 0.65495
# No improvement for 30 epochs.
# Epoch: 280 | Train Loss: 0.01641
# Epoch: 280 | Val Loss: 0.19491 | Accuracy: 0.95599 | Macro F1: 0.65924
# Best model saved for epoch 282 with Val Loss: 0.19038
# Epoch: 290 | Train Loss: 0.01615
# Epoch: 290 | Val Loss: 0.19455 | Accuracy: 0.95632 | Macro F1: 0.65429
# No improvement for 10 epochs.
# Epoch: 300 | Train Loss: 0.01522
# Epoch: 300 | Val Loss: 0.19970 | Accuracy: 0.95506 | Macro F1: 0.65273
# No improvement for 20 epochs.
# Best model saved for epoch 309 with Val Loss: 0.18949
# Epoch: 310 | Train Loss: 0.01501
# Epoch: 310 | Val Loss: 0.18812 | Accuracy: 0.95802 | Macro F1: 0.65519
# Best model saved for epoch 310 with Val Loss: 0.18812
# Epoch: 320 | Train Loss: 0.01488
# Epoch: 320 | Val Loss: 0.21506 | Accuracy: 0.95067 | Macro F1: 0.64787
# No improvement for 10 epochs.
# Epoch: 330 | Train Loss: 0.01362
# Epoch: 330 | Val Loss: 0.19259 | Accuracy: 0.95764 | Macro F1: 0.66076
# No improvement for 20 epochs.
# Epoch: 340 | Train Loss: 0.01337
# Epoch: 340 | Val Loss: 0.19178 | Accuracy: 0.95901 | Macro F1: 0.66063
# No improvement for 30 epochs.
# Epoch: 350 | Train Loss: 0.01284
# Epoch: 350 | Val Loss: 0.20620 | Accuracy: 0.95566 | Macro F1: 0.65208
# No improvement for 40 epochs.
# Epoch: 360 | Train Loss: 0.01235
# Epoch: 360 | Val Loss: 0.20179 | Accuracy: 0.95692 | Macro F1: 0.65819
# No improvement for 50 epochs.
# Early stopping triggered at epoch 360 after 50 epochs without improvement.

# %% [markdown]
# ### **3.4 Evaluate on test set**

# %%
print("\nEvaluating best model on test set...")
model.load_state_dict(torch.load(os.path.join(output_path, f'best_model.pth')))
model.eval()
with torch.no_grad():
    out = model(data.x_dict, data.edge_index_dict)
    test_loss = F.cross_entropy(
        out[test_idx],
        data['building'].y[test_idx]
    ).item()
    all_test_preds = out[test_idx].argmax(dim=1).cpu().numpy()
    all_test_labels = data['building'].y[test_idx].cpu().numpy()
    test_acc = (all_test_preds == all_test_labels).mean()
    test_macro_f1 = f1_score(all_test_labels, all_test_preds, average='macro')
    test_precision = precision_score(all_test_labels, all_test_preds, average='macro', zero_division=0)
    test_recall = recall_score(all_test_labels, all_test_preds, average='macro', zero_division=0)

    top2 = out[test_idx].topk(2, dim=1).indices
    true_labels = data['building'].y[test_idx].unsqueeze(1)
    test_top2_acc = (top2.eq(true_labels).sum(dim=1) > 0).float().mean().item()

    print(f'Test Loss: {test_loss:.5f} | Test Accuracy: {test_acc:.5f} | Test Macro F1: {test_macro_f1:.5f}')
    print(f'Test Precision: {test_precision:.5f} | Test Recall: {test_recall:.5f}')
    print(f'Test Top2 Accuracy: {test_top2_acc:.5f}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Evaluating best model on test set...
# Test Loss: 0.17871 | Test Accuracy: 0.95885 | Test Macro F1: 0.70389
# Test Precision: 0.70593 | Test Recall: 0.70747
# Test Top2 Accuracy: 0.99018

# %% [markdown]
# ## **4. HeteroGNN** (urban features + cross-view imagery)

# %% [markdown]
# ### **4.1 Visual feature extraction (VHR)**

# %%
svi_path        = f'data/svi/{city}'
vhr_path        = f'data/satellite/{city}'
embed_cv_model  = 'dinov3'
image_dimension = 256
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
vhr_embed = embedding_images(
        image_type = 'VHR',
        model_name = embed_cv_model,
        image_path = vhr_path,
        all_bids_graph = all_bids_graph,
        bid2node = bid2node,
        image_dimension = image_dimension,
        batch_size = batch_size,
        device = 'cuda',
        output_path = cache_path,
        city = city
        )

data['building'].vhr = vhr_embed
data['building'].x = torch.cat([
    data['building'].x,
    data['building'].vhr
], dim=1)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 137921 available images for VHR.
# Cache file loaded: Washington_VHR_256_dinov3_139076_137921.pt
# Building shape after embedding with image: torch.Size([139076, 527])

# %% [markdown]
# ### **4.2 Training**

# %%
model = HeteroSAGE(hidden_channels=hidden_dim, out_channels=num_classes, dropout_rate=.2).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)

best_epoch = 0
best_val_loss = float('inf')
patience_counter = 0
PATIENCE = 50

for epoch in range(EPOCH):
    model.train()
    optimizer.zero_grad()

    out = model(data.x_dict, data.edge_index_dict)
    train_loss = F.cross_entropy(
        out[train_idx],
        data['building'].y[train_idx],
        weight=class_weights
    )
    train_loss.backward()
    optimizer.step()

    model.eval()
    with torch.no_grad():
        out = model(data.x_dict, data.edge_index_dict)
        val_loss = F.cross_entropy(
            out[val_idx],
            data['building'].y[val_idx]
        )
        all_preds = out[val_idx].argmax(dim=1).cpu().numpy()
        all_labels = data['building'].y[val_idx].cpu().numpy()
        avg_acc = (all_preds == all_labels).mean()
        macro_f1 = f1_score(all_labels, all_preds, average='macro')
        
        scheduler.step(val_loss)
        
        if epoch % 10 == 0:
            print(f'Epoch: {epoch} | Train Loss: {train_loss.item():.5f}')
            print(f'Epoch: {epoch} | Val Loss: {val_loss.item():.5f} | Accuracy: {avg_acc:.5f} | Macro F1: {macro_f1:.5f}')
        
        if val_loss < best_val_loss and epoch > 10:
            best_val_loss = val_loss
            best_epoch = epoch
            torch.save(model.state_dict(), os.path.join(output_path, f'best_model.pth'))
            print(f"Best model saved for epoch {epoch} with Val Loss: {best_val_loss:.5f}")
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter % 10 == 0:
                print(f"No improvement for {patience_counter} epochs.")

    if patience_counter >= PATIENCE:
        print(f"Early stopping triggered at epoch {epoch} after {PATIENCE} epochs without improvement.")
        break
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Epoch: 0 | Train Loss: 2.61755
# Epoch: 0 | Val Loss: 2.43388 | Accuracy: 0.10750 | Macro F1: 0.06106
# No improvement for 10 epochs.
# Epoch: 10 | Train Loss: 0.60276
# Epoch: 10 | Val Loss: 0.85575 | Accuracy: 0.78814 | Macro F1: 0.43838
# Best model saved for epoch 11 with Val Loss: 0.79278
# Best model saved for epoch 12 with Val Loss: 0.71886
# Best model saved for epoch 13 with Val Loss: 0.65418
# Best model saved for epoch 14 with Val Loss: 0.61189
# Best model saved for epoch 15 with Val Loss: 0.57273
# Best model saved for epoch 16 with Val Loss: 0.52879
# Best model saved for epoch 17 with Val Loss: 0.48387
# Best model saved for epoch 18 with Val Loss: 0.45439
# Best model saved for epoch 19 with Val Loss: 0.43783
# Epoch: 20 | Train Loss: 0.28643
# Epoch: 20 | Val Loss: 0.42532 | Accuracy: 0.86907 | Macro F1: 0.50774
# Best model saved for epoch 20 with Val Loss: 0.42532
# Best model saved for epoch 21 with Val Loss: 0.40762
# Best model saved for epoch 22 with Val Loss: 0.37990
# Best model saved for epoch 23 with Val Loss: 0.35242
# Best model saved for epoch 24 with Val Loss: 0.33428
# Best model saved for epoch 25 with Val Loss: 0.31800
# Best model saved for epoch 26 with Val Loss: 0.30598
# Best model saved for epoch 27 with Val Loss: 0.29875
# Best model saved for epoch 28 with Val Loss: 0.29336
# Best model saved for epoch 29 with Val Loss: 0.28961
# Epoch: 30 | Train Loss: 0.17089
# Epoch: 30 | Val Loss: 0.28698 | Accuracy: 0.90853 | Macro F1: 0.56672
# Best model saved for epoch 30 with Val Loss: 0.28698
# Best model saved for epoch 31 with Val Loss: 0.28344
# Best model saved for epoch 32 with Val Loss: 0.28034
# Best model saved for epoch 33 with Val Loss: 0.27732
# Best model saved for epoch 34 with Val Loss: 0.27406
# Best model saved for epoch 35 with Val Loss: 0.27350
# Best model saved for epoch 36 with Val Loss: 0.27332
# Best model saved for epoch 37 with Val Loss: 0.27243
# Best model saved for epoch 38 with Val Loss: 0.26960
# Best model saved for epoch 39 with Val Loss: 0.26664
# Epoch: 40 | Train Loss: 0.10292
# Epoch: 40 | Val Loss: 0.26383 | Accuracy: 0.91692 | Macro F1: 0.57820
# Best model saved for epoch 40 with Val Loss: 0.26383
# Best model saved for epoch 41 with Val Loss: 0.26110
# Best model saved for epoch 42 with Val Loss: 0.25796
# Best model saved for epoch 43 with Val Loss: 0.25566
# Best model saved for epoch 44 with Val Loss: 0.25506
# Best model saved for epoch 45 with Val Loss: 0.25313
# Best model saved for epoch 46 with Val Loss: 0.25027
# Best model saved for epoch 47 with Val Loss: 0.24811
# Best model saved for epoch 48 with Val Loss: 0.24750
# Epoch: 50 | Train Loss: 0.06941
# Epoch: 50 | Val Loss: 0.24739 | Accuracy: 0.92515 | Macro F1: 0.61714
# Best model saved for epoch 50 with Val Loss: 0.24739
# Best model saved for epoch 51 with Val Loss: 0.24388
# Best model saved for epoch 52 with Val Loss: 0.23937
# Best model saved for epoch 53 with Val Loss: 0.23857
# Best model saved for epoch 54 with Val Loss: 0.23804
# Best model saved for epoch 55 with Val Loss: 0.23378
# Best model saved for epoch 56 with Val Loss: 0.22807
# Best model saved for epoch 57 with Val Loss: 0.22423
# Best model saved for epoch 58 with Val Loss: 0.22123
# Best model saved for epoch 59 with Val Loss: 0.21962
# Epoch: 60 | Train Loss: 0.05931
# Epoch: 60 | Val Loss: 0.22006 | Accuracy: 0.93481 | Macro F1: 0.63508
# Best model saved for epoch 66 with Val Loss: 0.21917
# Best model saved for epoch 67 with Val Loss: 0.21547
# Best model saved for epoch 68 with Val Loss: 0.21187
# Best model saved for epoch 69 with Val Loss: 0.21017
# Epoch: 70 | Train Loss: 0.05134
# Epoch: 70 | Val Loss: 0.20820 | Accuracy: 0.93854 | Macro F1: 0.65589
# Best model saved for epoch 70 with Val Loss: 0.20820
# Epoch: 80 | Train Loss: 0.04458
# Epoch: 80 | Val Loss: 0.20817 | Accuracy: 0.94041 | Macro F1: 0.67019
# Best model saved for epoch 80 with Val Loss: 0.20817
# Best model saved for epoch 87 with Val Loss: 0.20801
# Best model saved for epoch 88 with Val Loss: 0.20693
# Best model saved for epoch 89 with Val Loss: 0.20526
# Epoch: 90 | Train Loss: 0.04462
# Epoch: 90 | Val Loss: 0.20526 | Accuracy: 0.94063 | Macro F1: 0.66474
# Best model saved for epoch 93 with Val Loss: 0.20382
# Best model saved for epoch 94 with Val Loss: 0.19837
# Best model saved for epoch 95 with Val Loss: 0.19104
# Best model saved for epoch 96 with Val Loss: 0.18969
# Epoch: 100 | Train Loss: 0.04605
# Epoch: 100 | Val Loss: 0.19610 | Accuracy: 0.94430 | Macro F1: 0.66413
# No improvement for 10 epochs.
# Best model saved for epoch 107 with Val Loss: 0.18921
# Best model saved for epoch 108 with Val Loss: 0.18745
# Epoch: 110 | Train Loss: 0.03201
# Epoch: 110 | Val Loss: 0.20593 | Accuracy: 0.94370 | Macro F1: 0.66465
# Best model saved for epoch 113 with Val Loss: 0.18600
# Best model saved for epoch 118 with Val Loss: 0.18573
# Best model saved for epoch 119 with Val Loss: 0.18301
# Epoch: 120 | Train Loss: 0.03313
# Epoch: 120 | Val Loss: 0.18056 | Accuracy: 0.95171 | Macro F1: 0.66532
# Best model saved for epoch 120 with Val Loss: 0.18056
# Best model saved for epoch 121 with Val Loss: 0.17838
# Best model saved for epoch 122 with Val Loss: 0.17821
# Best model saved for epoch 123 with Val Loss: 0.17804
# Epoch: 130 | Train Loss: 0.02915
# Epoch: 130 | Val Loss: 0.18837 | Accuracy: 0.94963 | Macro F1: 0.67200
# No improvement for 10 epochs.
# Best model saved for epoch 135 with Val Loss: 0.17473
# Epoch: 140 | Train Loss: 0.03432
# Epoch: 140 | Val Loss: 0.17701 | Accuracy: 0.95500 | Macro F1: 0.66557
# No improvement for 10 epochs.
# Epoch: 150 | Train Loss: 0.02894
# Epoch: 150 | Val Loss: 0.20897 | Accuracy: 0.94601 | Macro F1: 0.66606
# No improvement for 20 epochs.
# Epoch: 160 | Train Loss: 0.02645
# Epoch: 160 | Val Loss: 0.19324 | Accuracy: 0.95072 | Macro F1: 0.66873
# No improvement for 30 epochs.
# Epoch: 170 | Train Loss: 0.02975
# Epoch: 170 | Val Loss: 0.17307 | Accuracy: 0.95649 | Macro F1: 0.67337
# Best model saved for epoch 170 with Val Loss: 0.17307
# Best model saved for epoch 171 with Val Loss: 0.17274
# Epoch: 180 | Train Loss: 0.01895
# Epoch: 180 | Val Loss: 0.17732 | Accuracy: 0.95489 | Macro F1: 0.65366
# No improvement for 10 epochs.
# Epoch: 190 | Train Loss: 0.01868
# Epoch: 190 | Val Loss: 0.18155 | Accuracy: 0.95791 | Macro F1: 0.66444
# No improvement for 20 epochs.
# Best model saved for epoch 199 with Val Loss: 0.17260
# Epoch: 200 | Train Loss: 0.01583
# Epoch: 200 | Val Loss: 0.17280 | Accuracy: 0.95967 | Macro F1: 0.67472
# Best model saved for epoch 203 with Val Loss: 0.16881
# Best model saved for epoch 204 with Val Loss: 0.16880
# Epoch: 210 | Train Loss: 0.01321
# Epoch: 210 | Val Loss: 0.17427 | Accuracy: 0.96181 | Macro F1: 0.68303
# No improvement for 10 epochs.
# Epoch: 220 | Train Loss: 0.01269
# Epoch: 220 | Val Loss: 0.18422 | Accuracy: 0.96077 | Macro F1: 0.67563
# No improvement for 20 epochs.
# Epoch: 230 | Train Loss: 0.01049
# Epoch: 230 | Val Loss: 0.18372 | Accuracy: 0.96148 | Macro F1: 0.67655
# No improvement for 30 epochs.
# Epoch: 240 | Train Loss: 0.01002
# Epoch: 240 | Val Loss: 0.18283 | Accuracy: 0.96181 | Macro F1: 0.67356
# No improvement for 40 epochs.
# Epoch: 250 | Train Loss: 0.00856
# Epoch: 250 | Val Loss: 0.17925 | Accuracy: 0.96345 | Macro F1: 0.68566
# No improvement for 50 epochs.
# Early stopping triggered at epoch 254 after 50 epochs without improvement.

# %% [markdown]
# ### **4.3 Evaluate on test set**

# %%
print("\nEvaluating best model on test set...")
model.load_state_dict(torch.load(os.path.join(output_path, f'best_model.pth')))
model.eval()
with torch.no_grad():
    out = model(data.x_dict, data.edge_index_dict)
    test_loss = F.cross_entropy(
        out[test_idx],
        data['building'].y[test_idx]
    ).item()
    all_test_preds = out[test_idx].argmax(dim=1).cpu().numpy()
    all_test_labels = data['building'].y[test_idx].cpu().numpy()
    test_acc = (all_test_preds == all_test_labels).mean()
    test_macro_f1 = f1_score(all_test_labels, all_test_preds, average='macro')
    test_precision = precision_score(all_test_labels, all_test_preds, average='macro', zero_division=0)
    test_recall = recall_score(all_test_labels, all_test_preds, average='macro', zero_division=0)

    top2 = out[test_idx].topk(2, dim=1).indices
    true_labels = data['building'].y[test_idx].unsqueeze(1)
    test_top2_acc = (top2.eq(true_labels).sum(dim=1) > 0).float().mean().item()

    print(f'Test Loss: {test_loss:.5f} | Test Accuracy: {test_acc:.5f} | Test Macro F1: {test_macro_f1:.5f}')
    print(f'Test Precision: {test_precision:.5f} | Test Recall: {test_recall:.5f}')
    print(f'Test Top2 Accuracy: {test_top2_acc:.5f}')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Evaluating best model on test set...
# Test Loss: 0.14976 | Test Accuracy: 0.96417 | Test Macro F1: 0.74082
# Test Precision: 0.72767 | Test Recall: 0.76154
# Test Top2 Accuracy: 0.99139
